# %% [markdown]
# # Multilayer perceptron

# %% [markdown]
# Tensorflow framework documentation [here](https://www.tensorflow.org/) \
# Keras framework documentation [here](https://keras.io/)

# %%
import os

# This guide can only be run with the torch backend.
os.environ["KERAS_BACKEND"] = "torch"

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %% [markdown]
# ## Load data - California Housing

# %%
# Load MNIST data
data = pd.read_csv( _ , header=None)

X = _
y = _

print (X.shape, y.shape)

# %%
# Scale data using z-score
scaler_X = StandardScaler()
X_scaled = scaler_X.fit_transform( _ )

scaler_y = StandardScaler()
y_scaled = scaler_y.fit_transform( _ )

# Reformat data (samples, timesteps, features)
X_seq = X_scaled.reshape( _ , _ , 1)

# create train / test splits
X_train, X_test, y_train, y_test = _


print (X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %% [markdown]
# ## Create a graph model

# %%
# Create the model
model = Sequential()
model.add(Dense( _ , input_shape = _ , activation = _ ))
model.add(Dense( _ , activation = _ ))
model.add(Dense( _ , activation = _ ))

# %%
# Create the model

model = Sequential()
model.add(LSTM( _ , activation='tanh', input_shape=( _ , _ ), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM ( _ , activation='tanh'))
model.add(Dense( _ , activation='relu'))
model.add(Dense( _ ))  # Continouos predictions

# %% [markdown]
# ## Define loss function and optimizer

# %%
# Configure the model and start training
model.compile(loss = _ , optimizer = _ , metrics = _ )

# %% [markdown]
# ## Train model

# %%
history = model.fit( _ , _ , \
                    epochs = _ , batch_size = , \
                    verbose = , validation_split = 0.2)

# %% [markdown]
# ## Plot results

# %%
# Plot progress (loss function)

# %% [markdown]
# ## Compute metrics over ```X_test``` images

# %%
# Test the model after training
test_results = model.predict( _ )
