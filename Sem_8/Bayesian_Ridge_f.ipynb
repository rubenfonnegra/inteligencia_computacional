# %% [markdown]
# # **Bayesian Ridge Regression**

# %% [markdown]
# Download the [Energy efficiency](https://www.kaggle.com/datasets/elikplim/eergy-efficiency-dataset?resource=download) dataset [here](https://drive.google.com/file/d/1UpP1DoN0WQigaD0y-A75GlD-bJ2TAjMW/view?usp=drive_link) \
# ```BayesianRidge``` module documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.BayesianRidge.html)

# %% [markdown]
# ## In Synthetic data

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_regression
from sklearn.linear_model import BayesianRidge, LinearRegression
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples = 500, n_features = 1, noise = 10, random_state = 1)

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split( X , y , test_size = 0.20, random_state = 1)

_, ax = plt.subplots (figsize=(6,5))
ax.scatter(X, y, c='b')
print (X.shape, y.shape)
# Out:
# (500, 1) (500,)

# %%
# 2. Entrenar modelo Bayesian Ridge
model_bayes = BayesianRidge()
model_bayes.fit(X_train, y_train)

# 3. Entrenar modelo Linear Regression
model_linear = LinearRegression()
model_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 4. Predicciones en nuevos datos
y_mean_bayes, y_std_bayes = model_bayes.predict(X_test, return_std=True)
y_pred_linear = model_linear.predict(X_test)

# %%
# 5. Visualización
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', alpha=0.5, label='Real data')

plt.plot(X_test, y_mean_bayes, color='green', label='Bayesian Ridge: Mean pred')

plt.fill_between(X_test.ravel(), y_mean_bayes - y_std_bayes, y_mean_bayes + y_std_bayes,
                 color='g', alpha=0.3, label='Bayesian Ridge: uncertainty (±1σ)')

plt.plot(X_test, y_pred_linear, color='red', linestyle='--', label='Linear Regression')
plt.title('Bayesian Ridge vs Linear Regression')

plt.legend()
# plt.grid(True)
plt.show()

# %% [markdown]
# ## In real data

# %% [markdown]
# Download the [Energy efficiency](https://www.kaggle.com/datasets/elikplim/eergy-efficiency-dataset?resource=download) dataset [here](https://drive.google.com/file/d/1UpP1DoN0WQigaD0y-A75GlD-bJ2TAjMW/view?usp=drive_link) \
# ```linear_regression``` documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html?highlight=linear%20regression#sklearn.linear_model.LinearRegression)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Cargar el archivo CSV
data = pd.read_csv( _ )

# Mostrar las primeras filas del DataFrame
data.head()

# splitting the dataset into features and targets
y = _
X = _

# check features
features = list(X.columns)

# %%
# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split( _ , _ , test_size = 0.20, random_state = 1)

# standardize the data
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# train the model and make predictions
svr_ = BayesianRidge()
y_pred = _

# %%
# Plot the results 

_, axes = plt.subplots (1,2, figsize=(8,4))
axes[0].scatter( _ , _ )
axes[0].scatter( _ , _ )

# %%
# calculate the MSE
print('MSE of predicting load: \n', mean_squared_error( _ , _ ))
print('')

# calculate the MAE
print('MAE of predicting load: \n', mean_absolute_error( _ , _ ))
