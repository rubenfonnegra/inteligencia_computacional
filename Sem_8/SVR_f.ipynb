# %% [markdown]
# # **Support Vector Regresion (SVR)**

# %% [markdown]
# ```SVR``` module documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html)

# %% [markdown]
# ## In Synthetic data

# %%
import numpy as np # Librería mateamtica
import matplotlib.pyplot as plt # plots

from sklearn.svm import SVR
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples = 500, n_features = 1, noise = 10, random_state = 1)

_, ax = plt.subplots (figsize=(6,5))
ax.scatter(X, y, c='b')
print (X.shape, y.shape)
# Out:
# (500, 1) (500,)

# %%
svr = SVR(kernel="linear")

svr.fit(X, y)

# %%
# Predecir la nueva muestra. Imprimir la prediccion
prediction = svr.predict( _ )
print (prediction)

# %%
# Predict x values 
predictions = svr.predict( _ )

# Draw real samples (blue) and predictions (red)
_, ax = plt.subplots (figsize = ( _ , _ ))
ax.scatter( _ , _ , color = 'blue')
ax.plot ( _ , _ , color = 'red')

# %% [markdown]
# ## In real data

# %% [markdown]
# Download the [Energy efficiency](https://www.kaggle.com/datasets/elikplim/eergy-efficiency-dataset?resource=download) dataset [here](https://drive.google.com/file/d/1UpP1DoN0WQigaD0y-A75GlD-bJ2TAjMW/view?usp=drive_link) \
# ```linear_regression``` documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html?highlight=linear%20regression#sklearn.linear_model.LinearRegression)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Cargar el archivo CSV
file_path = "../Data/energy_efficiency_curated.csv"
data = pd.read_csv(file_path)

# Mostrar las primeras filas del DataFrame
data.head()

# splitting the dataset into features and targets
y1 = data['heating_load']
y2 = data['cooling_load']
X = data.drop(['heating_load','cooling_load'], axis = 1)

# check features
features = list(X.columns)

# %%
# split the dataset into training and testing sets
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size = 0.30, random_state=seed)
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, test_size = 0.30, random_state=seed)

# standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# train the model and make predictions for heating_load
svr_heating = SVR()
y1_pred = svr_heating.fit(X_train, y1_train).predict(X_test)

# train the model and make predictions for cooling_load
svr_cooling = SVR()
y2_pred = svr_cooling.fit(X_train, y2_train).predict(X_test)

# %%
_, axes = plt.subplots (1,2, figsize=(8,4))
axes[0].scatter(X_test[:, 0], y1_test)
axes[0].scatter(X_test[:, 0], y1_pred)

axes[1].scatter(X_test[:, 0], y2_test)
axes[1].scatter(X_test[:, 0], y1_pred)

# %%
# calculate the MSE
print('MSE of predicting heating load: \n', mean_squared_error(y1_test, y1_pred))
print('MSE of predicting cooling load: \n', mean_squared_error(y2_test, y2_pred))
print('')

# calculate the MAE
print('MAE of predicting heating load: \n', mean_absolute_error(y1_test, y1_pred))
print('MAE of predicting cooling load: \n', mean_absolute_error(y2_test, y2_pred))
# Out:
# MSE of predicting heating load:
#  7.872123284703641
# MSE of predicting cooling load:
#  11.164739477446517
#
# MAE of predicting heating load:
#  1.7395678964394274
# MAE of predicting cooling load:
#  2.134418270055192
