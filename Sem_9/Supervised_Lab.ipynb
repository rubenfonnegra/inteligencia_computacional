# %%
#@markdown ------
#@markdown # **⚠️ Install dependencies ⚠️**
# !gdown -qq "https://drive.google.com/uc?id=1kubf996AWrBqJGtaBnOQgBMFQFrVHKpF" -O /Supervised_Lab-1.1-py3-none-any.whl
# !pip3 -qq install /Supervised_Lab-1.1-py3-none-any.whl
# !pip3 -qq install gradio scikit-learn matplotlib pandas
# !rm -r /Supervised_Lab-1.1-py3-none-any.whl
# !pip3 show Supervised_Lab
#@markdown ------

# %%
from Supervised_Lab import run_supervised_lab
lab = run_supervised_lab()

# %%
lab.close()
