# %% [markdown]
# # **K-Means - Real data**
#
# Useful dataset: [fruits dataset](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link) \
# Useful dataset: [Mall customers dataset](https://drive.google.com/file/d/1jACghC-it0Hlb091tc2BH_RgrFWOXXih/view?usp=sharing)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("datasets/Mall_Customers/Mall_Customers.csv")
X = np.c_[data.iloc[:, -2], data.iloc[:, -1]]

plt.scatter( X[:,0] , X[:,1] , cmap = plt.cm.Paired)
print (X.shape)

# %% [markdown]
# ## **Elbow and Silhouette method**

# %%
_, axes = plt.subplots(1,2,figsize=(15,5))

model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,10), metric='silhouette', ax=axes[0])
visualizer.fit(X)
axes[0].set_title('Silhouette')

visualizer = KElbowVisualizer(model, k=(2,10), metric='distortion', ax=axes[1])
visualizer.fit(X)
axes[1].set_title('Distortion')

# %% [markdown]
# ## **Clustering**

# %%
kmeans = KMeans ( n_clusters = _ ).fit( _ )
centroids = kmeans.cluster_centers_
print(centroids)

# %%
predictions = kmeans.predict( _ )

# %%
# Plot decision boundaries
_

# %% [markdown]
# # **Agglomerative Clustering**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/content/Mall_Customers.csv")
X = np.c_[data.iloc[:, -2], data.iloc[:, -1]]

plt.scatter( X[:,0] , X[:,1] , cmap = plt.cm.Paired)
print (X.shape)

# %%
plt.figure(figsize =(12, 8))
plt.title('Dendrogram')
Dendrogram = dendrogram((linkage(X, method='ward')))
# plt.show()
plt.savefig("a.png",dpi = 250)

# %%
model = AgglomerativeClustering(distance_threshold=None, n_clusters=5)
predictions = model.fit_predict(X)

# %%
# predictions
plt.scatter(X[:,0], X[:,1], c=predictions, cmap='Paired')
